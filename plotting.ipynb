# %% [markdown]
# # Plotting
# ## The following file comprises the plots for the various experiments that we run

# %%
import sys
import os
  
# getting the name of the directory
# where the this file is present.
current = os.path.abspath('')

from parameters import *
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### Path for saving all plots

# %%
plot_path = "/experiments/results/plots/"

# %% [markdown]
# ### Define m_list for Strassen's and recursive write through

# %%
m_list = [0,2,4,8,16,32,64,128]
m_legend = ["m="+str(m) for m in m_list]

# %%
n_ticks = [8,16,32,64,128,256]
n_label = [str(tick) for tick in n_ticks]

# %% [markdown]
# ### RUN ALL CODE ABOVE

# %% [markdown]
# ## Recursive Write Through m-tests Plotting

# %% [markdown]
# ### Paths and Dataframe creation

# %%
#insert the relative path
relative_path = "/experiments/results/write_through_m_experiments/"

# %%
name = "_recursive_write_through_matrix_multiplication_mtest.csv"

recursive_write_through_res = {}

for i in range(len(m_list)):
    df_name = "df_m"+str(m_list[i])
    df = pd.read_csv(current + relative_path + str(m_list[i]) + name)
    df = df[df.index > 1]
    df['nano_seconds/runtime'] = df.apply(lambda x: (1000000000*x['time']) / x['n']**3, axis=1)
    
    recursive_write_through_res[df_name] = df

# %% [markdown]
# ### Plotting

# %%
fig = plt.figure()
ax = fig.gca()

for m in m_list:
    name = "df_m" + str(m)
    df = recursive_write_through_res[name]
    ax.errorbar(df['n'], df['nano_seconds/runtime'], capsize = 3.0, marker = 'o')

ax.set_yscale('log', base=2)
ax.set_xscale('log', base=2)
plt.xticks(n_ticks, n_label)

#outside for-loop
ax.set_xlabel("n")
ax.set_ylabel("log time (nano s/runtime)")
ax.legend(m_legend)

#save plot as pdf
plt.savefig(current+plot_path+ "recursive_write_through_m_experiment_runtime_loglog_scaled.pdf")

# %% [markdown]
# ## Strassen's m-tests Plotting

# %% [markdown]
# ### Paths and Dataframe creation

# %%
#insert the relative path
relative_path = "/experiments/results/strassen_m_experiments/"

# %%
name = "_strassen_matrix_multiplication_mtest.csv"

strassens_res = {}

for i in range(len(m_list)):
    df_name = "df_m"+str(m_list[i])
    df = pd.read_csv(current + relative_path + str(m_list[i]) + name)
    df = df[df.index > 1]
    df['nano_seconds/runtime'] = df.apply(lambda x: (1000000000*x['time']) / x['n']**2.8, axis=1)
    
    strassens_res[df_name] = df

# %% [markdown]
# ### Plotting

# %%
fig = plt.figure()
ax = fig.gca()

for m in m_list:
    name = "df_m" + str(m)
    df = strassens_res[name]
    ax.errorbar(df['n'], df['nano_seconds/runtime'], capsize = 3.0, marker = 'o')

ax.set_yscale('log', base=2)
ax.set_xscale('log', base=2)
plt.xticks(n_ticks, n_label)


#outside for-loop
ax.set_xlabel("n")
ax.set_ylabel("time (nano s/runtime)")
ax.legend(m_legend)

#save plot as pdf
plt.savefig(current+plot_path+ "strassen_m_experiment_runtime_loglog_scaled.pdf")

# %% [markdown]
# ## New plots for max n=256

# %%
m_list = [4,8,16,32,64,128]
m_legend = ["m="+str(m) for m in m_list]
n_ticks = [8,16,32,64,128,256]
n_label = [str(tick) for tick in n_ticks]
computer = "GG"

# %% [markdown]
# ### Recursive write through

# %%
write_through_relative_path = "/experiments/results/write_through_m_experiments/"
name = "_recursive_write_through_matrix_multiplication_mtest.csv"

recursive_write_through_res = {}

for i in range(len(m_list)):
    df_name = "df_m"+str(m_list[i])
    df = pd.read_csv(current + write_through_relative_path + str(m_list[i]) + name)
    df = df[df.index > 1]
    df['nano_seconds/runtime'] = df.apply(lambda x: (1000000000*x['time']) / x['n']**3, axis=1)
    
    recursive_write_through_res[df_name] = df

# %%
fig = plt.figure()
ax = fig.gca()

for m in m_list:
    name = "df_m" + str(m)
    label = "m=" + str(m)
    df = recursive_write_through_res[name]
    ax.plot(df['n'], df['time'], label=label, marker = 'o')

# ax.set_yscale('log', base=2)
ax.set_xscale('log', base=2)
plt.xticks(n_ticks, n_label)

#outside for-loop
ax.set_xlabel("n")
ax.set_ylabel("time (s)")
ax.legend(m_legend)

#save plot as pdf
plt.savefig(current+plot_path+ "recursive_write_through_m_experiment_new_plain_no_small_m.pdf")

# %%
fig = plt.figure()
ax = fig.gca()

for m in m_list:
    name = "df_m" + str(m)
    label = "m=" + str(m)
    df = recursive_write_through_res[name]
    ax.plot(df['n'], df['nano_seconds/runtime'], label=label, marker = 'o')

# ax.set_yscale('log', base=2)
ax.set_xscale('log', base=2)
plt.xticks(n_ticks, n_label)

#outside for-loop
ax.set_xlabel("n")
ax.set_ylabel("log time (nano s)")
ax.legend(m_legend)

#save plot as pdf
plt.savefig(current+plot_path+ "recursive_write_through_m_experiment_new_runtime_scaled_no_small_m.pdf")

# %% [markdown]
# ### Strassen

# %%
strassen_relative_path = "/experiments/results/strassen_m_experiments/"
name = "_strassen_matrix_multiplication_mtest.csv"

strassens_res = {}

for i in range(len(m_list)):
    df_name = "df_m"+str(m_list[i])
    df = pd.read_csv(current + strassen_relative_path + str(m_list[i]) + name)
    df = df[df.index > 1]
    df['nano_seconds/runtime'] = df.apply(lambda x: (1000000000*x['time']) / x['n']**2.8, axis=1)
    
    strassens_res[df_name] = df

# %%
fig = plt.figure()
ax = fig.gca()

for m in m_list:
    name = "df_m" + str(m)
    label="m=" + str(m)
    df = strassens_res[name]
    ax.plot(df['n'], df['time'], label=label, marker = 'o')

# ax.set_yscale('log', base=2)
ax.set_xscale('log', base=2)
plt.xticks(n_ticks, n_label)


#outside for-loop
ax.set_xlabel("n")
ax.set_ylabel("time (s)")
ax.legend(m_legend)

#save plot as pdf
plt.savefig(current+plot_path+ "strassen_m_experiment_new_plain_no_small_m.pdf")

# %%
fig = plt.figure()
ax = fig.gca()

for m in m_list:
    name = "df_m" + str(m)
    label="m=" + str(m)
    df = strassens_res[name]
    ax.plot(df['n'], df['nano_seconds/runtime'], label=label, marker = 'o')

ax.set_yscale('log', base=2)
ax.set_xscale('log', base=2)
plt.xticks(n_ticks, n_label)


#outside for-loop
ax.set_xlabel("n")
ax.set_ylabel("log time (nano s)")
ax.legend(m_legend)

#save plot as pdf
plt.savefig(current+plot_path+computer+ "strassen_m_experiment_new_runtime_scaled_no_small_m.pdf")

# %% [markdown]
# ## Plotting Horse Race

# %%
n_ticks_horse = [2,4,8,16,32,64,128,256]
n_label_horse = [str(tick) for tick in n_ticks_horse]
computer = "GG_"

names = ["elementary_multiplication_race",
        "elementary_transposed_multiplication_race",       
        "tiled_multiplication_race",
        "recursive_copying_multiplication_race",
        "recursive_write_through_multiplication_race",
        "strassen_multiplication_race",
        ]
horse_race = [computer + name + ".csv" for name in names]

print(horse_race)

relative_path_horse_race = "/horse_race/results/"
# Out:
# ['GG_elementary_multiplication_race.csv', 'GG_elementary_transposed_multiplication_race.csv', 'GG_tiled_multiplication_race.csv', 'GG_recursive_copying_multiplication_race.csv', 'GG_recursive_write_through_multiplication_race.csv', 'GG_strassen_multiplication_race.csv']

# %%
horse_race_res = {}

for i in range(len(horse_race)):
    df_name = names[i]
    df = pd.read_csv(current + relative_path_horse_race + horse_race[i])
    
    df['nano_seconds/runtime'] = df.apply(lambda x: (1000000000*x['time']) / x['n']**3.0, axis=1)
    horse_race_res[df_name] = df

# %%
horse_race_res["strassen_multiplication_race"]
# Out:
#      n      time          stdv  nano_seconds/runtime
# 0    2  0.000007  3.641904e-07            844.399134
# 1    4  0.000037  3.641904e-07            583.628813
# 2    8  0.000331  8.036982e-06            646.958748
# 3   16  0.001906  1.670243e-04            465.428457
# 4   32  0.012821  5.661848e-04            391.267046
# 5   64  0.090449  4.253191e-04            345.037430
# 6  128  0.611892  2.409683e-04            291.772722
# 7  256  4.262170  3.451533e-03            254.045148

# %% [markdown]
# ### Generating tables for latex

# %%
for name in names:
    print(name)
    print(horse_race_res[name].to_latex(caption=name+" results"))
# Out:
# elementary_multiplication_race
# \begin{table}
# \centering
# \caption{elementary_multiplication_race results}
# \begin{tabular}{lrrrr}
# \toprule
# {} &    n &      time &          stdv &  nano\_seconds/runtime \\
# \midrule
# 0 &    2 &  0.000006 &  3.641904e-07 &            794.728597 \\
# 1 &    4 &  0.000073 &  3.779166e-05 &           1134.971778 \\
# 2 &    8 &  0.000277 &  1.740673e-05 &            540.477534 \\
# 3 &   16 &  0.001781 &  1.551248e-04 &            434.927642 \\
# 4 &   32 &  0.013024 &  3.113044e-04 &            397.458886 \\
# 5 &   64 &  0.097294 &  8.575994e-04 &            371.147811 \\
# 6 &  128 &  0.772442 &  2.838363e-02 &            368.328983 \\
# 7 &  256 &  5.945595 &  8.985034e-03 &            354.385084 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# elementary_transposed_multiplication_race
# \begin{table}
# \centering
# \caption{elementary_transposed_multiplication_race results}
# \begin{tabular}{lrrrr}
# \toprule
# {} &    n &      time &          stdv &  nano\_seconds/runtime \\
# \midrule
# 0 &    2 &  0.000007 &  7.664085e-07 &            874.201457 \\
# 1 &    4 &  0.000047 &  2.175365e-05 &            741.332769 \\
# 2 &    8 &  0.000261 &  3.251946e-05 &            509.433448 \\
# 3 &   16 &  0.001915 &  3.008783e-04 &            467.640348 \\
# 4 &   32 &  0.013720 &  3.087911e-04 &            418.690130 \\
# 5 &   64 &  0.098792 &  2.661016e-03 &            376.861256 \\
# 6 &  128 &  0.750998 &  4.252302e-03 &            358.103951 \\
# 7 &  256 &  5.913399 &  4.083528e-02 &            352.466046 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# tiled_multiplication_race
# \begin{table}
# \centering
# \caption{tiled_multiplication_race results}
# \begin{tabular}{lrrrr}
# \toprule
# {} &    n &       time &      stdv &  nano\_seconds/runtime \\
# \midrule
# 0 &    2 &   0.000114 &  0.000024 &          14295.180639 \\
# 1 &    4 &   0.000281 &  0.000093 &           4392.117262 \\
# 2 &    8 &   0.000717 &  0.000067 &           1400.243491 \\
# 3 &   16 &   0.008696 &  0.000141 &           2123.124432 \\
# 4 &   32 &   0.044537 &  0.000432 &           1359.175561 \\
# 5 &   64 &   0.304559 &  0.000336 &           1161.799446 \\
# 6 &  128 &   2.316262 &  0.003941 &           1104.479982 \\
# 7 &  256 &  18.219651 &  0.013749 &           1085.975844 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# recursive_copying_multiplication_race
# \begin{table}
# \centering
# \caption{recursive_copying_multiplication_race results}
# \begin{tabular}{lrrrr}
# \toprule
# {} &    n &       time &      stdv &  nano\_seconds/runtime \\
# \midrule
# 0 &    2 &   0.000048 &  0.000024 &           5980.332692 \\
# 1 &    4 &   0.000423 &  0.000037 &           6607.423226 \\
# 2 &    8 &   0.002388 &  0.000379 &           4664.994776 \\
# 3 &   16 &   0.019572 &  0.000537 &           4778.344495 \\
# 4 &   32 &   0.140677 &  0.001218 &           4293.125433 \\
# 5 &   64 &   1.084478 &  0.002988 &           4136.953976 \\
# 6 &  128 &   8.562554 &  0.010659 &           4082.944088 \\
# 7 &  256 &  68.827789 &  0.293615 &           4102.455885 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# recursive_write_through_multiplication_race
# \begin{table}
# \centering
# \caption{recursive_write_through_multiplication_race results}
# \begin{tabular}{lrrrr}
# \toprule
# {} &    n &      time &          stdv &  nano\_seconds/runtime \\
# \midrule
# 0 &    2 &  0.000009 &  4.145559e-06 &           1142.422358 \\
# 1 &    4 &  0.000036 &  2.384186e-07 &            569.969416 \\
# 2 &    8 &  0.000300 &  1.714792e-05 &            585.801899 \\
# 3 &   16 &  0.001913 &  4.276741e-04 &            466.941856 \\
# 4 &   32 &  0.014431 &  2.937027e-04 &            440.411289 \\
# 5 &   64 &  0.105869 &  1.890130e-03 &            403.856878 \\
# 6 &  128 &  0.808589 &  7.439260e-03 &            385.565196 \\
# 7 &  256 &  6.537513 &  5.919515e-02 &            389.666151 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# strassen_multiplication_race
# \begin{table}
# \centering
# \caption{strassen_multiplication_race results}
# \begin{tabular}{lrrrr}
# \toprule
# {} &    n &      time &          stdv &  nano\_seconds/runtime \\
# \midrule
# 0 &    2 &  0.000007 &  3.641904e-07 &            844.399134 \\
# 1 &    4 &  0.000037 &  3.641904e-07 &            583.628813 \\
# 2 &    8 &  0.000331 &  8.036982e-06 &            646.958748 \\
# 3 &   16 &  0.001906 &  1.670243e-04 &            465.428457 \\
# 4 &   32 &  0.012821 &  5.661848e-04 &            391.267046 \\
# 5 &   64 &  0.090449 &  4.253191e-04 &            345.037430 \\
# 6 &  128 &  0.611892 &  2.409683e-04 &            291.772722 \\
# 7 &  256 &  4.262170 &  3.451533e-03 &            254.045148 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
fig = plt.figure()
ax = fig.gca()

# #dropping tiled and copying to get better picture

#Easy representation
m_legend_horse_race = [name.split("_m")[0] for name in names]
#prettier visualization:
#m_legend_horse_race = ["elementary", "transposed", "tiled", "copying", "write_through", "strassen"]

for name in names:
    df = horse_race_res[name]
    label = name.split("_m")[0]
    if label == "elementary_transposed":
        label = label.split("_")[1]
    elif label == "recursive_copying":
        label = label.split("_")[1]
    elif label == "recursive_write_through":
        label = label.split("_")[1] + "_" + label.split("_")[2]
    ax.plot(df['n'], df['time'], label=label, marker="o")

ax.set_xscale('log', base=2)
plt.xticks(n_ticks_horse, n_label_horse)


#outside for-loop
ax.set_xlabel("n")
ax.set_ylabel("time(s)")
ax.legend()

#save plot as pdf
plt.savefig(current + plot_path + computer +"horse_race256_plain_log_y.pdf")

# %%
fig = plt.figure()
ax = fig.gca()

# #dropping tiled and copying to get better picture

#Easy representation
m_legend_horse_race = [name.split("_m")[0] for name in names]
#prettier visualization:
#m_legend_horse_race = ["elementary", "transposed", "tiled", "copying", "write_through", "strassen"]

for name in names:
    df = horse_race_res[name]
    label = name.split("_m")[0]
    if label == "elementary_transposed":
        label = label.split("_")[1]
    elif label == "recursive_copying":
        label = label.split("_")[1]
    elif label == "recursive_write_through":
        label = label.split("_")[1] + "_" + label.split("_")[2]
    ax.plot(df['n'], df['time'], label=label, marker="o")

ax.set_yscale('log', base=2)
ax.set_xscale('log', base=2)
plt.xticks(n_ticks_horse, n_label_horse)


#outside for-loop
ax.set_xlabel("n")
ax.set_ylabel("log time(s)")
ax.legend()

#save plot as pdf
plt.savefig(current + plot_path + computer +"horse_race256_loglog.pdf")

# %%
fig = plt.figure()
ax = fig.gca()

for name in names:
    df = horse_race_res[name]
    label = name.split("_m")[0]
    if label == "elementary_transposed":
        label = label.split("_")[1]
    elif label == "recursive_copying":
        label = label.split("_")[1]
    elif label == "recursive_write_through":
        label = label.split("_")[1] + "_" + label.split("_")[2]
    ax.plot(df['n'], df['nano_seconds/runtime'], label=label, marker="o")

ax.set_yscale('log', base=2)
ax.set_xscale('log', base=2)
plt.xticks(n_ticks_horse, n_label_horse)

#outside for-loop
ax.set_xlabel("n")
ax.set_ylabel("log time(nano sec/runtime)")
ax.legend(loc='lower left', bbox_to_anchor=(0.6,0.5))


#save plot as pdf
plt.savefig(current+plot_path+ computer+"horse_race256_runtime_scaled.pdf")

# %% [markdown]
# ## Plotting Horse Race with m=0

# %%
n_ticks_horse = [2,4,8,16,32,64,128,256]
n_label_horse = [str(tick) for tick in n_ticks_horse]
computer = "GG_M0FORALL"

names = ["elementary_multiplication_race",
        "elementary_transposed_multiplication_race",       
        "tiled_multiplication_race",
        "recursive_copying_multiplication_race",
        "recursive_write_through_multiplication_race",
        "strassen_multiplication_race",
        ]
horse_race = [computer + name + ".csv" for name in names]

print(horse_race)

relative_path_horse_race = "/horse_race/results/"
# Out:
# ['GG_M0FORALLelementary_multiplication_race.csv', 'GG_M0FORALLelementary_transposed_multiplication_race.csv', 'GG_M0FORALLtiled_multiplication_race.csv', 'GG_M0FORALLrecursive_copying_multiplication_race.csv', 'GG_M0FORALLrecursive_write_through_multiplication_race.csv', 'GG_M0FORALLstrassen_multiplication_race.csv']

# %%
horse_race_m0_res = {}

for i in range(len(horse_race)):
    df_name = names[i]
    df = pd.read_csv(current + relative_path_horse_race + horse_race[i])
    
    df['nano_seconds/runtime'] = df.apply(lambda x: (1000000000*x['time']) / x['n']**3.0, axis=1)
    horse_race_m0_res[df_name] = df

# %%
fig = plt.figure()
ax = fig.gca()

for name in names:
    df = horse_race_m0_res[name]
    label = name.split("_m")[0]
    if label == "elementary_transposed":
        label = label.split("_")[1]
    elif label == "recursive_copying":
        label = label.split("_")[1]
    elif label == "recursive_write_through":
        label = label.split("_")[1] + "_" + label.split("_")[2]
    ax.plot(df['n'], df['time'], label=label, marker="o")

ax.set_xscale('log', base=2)
plt.xticks(n_ticks_horse, n_label_horse)


#outside for-loop
ax.set_xlabel("n")
ax.set_ylabel("time(s)")
ax.legend()

#save plot as pdf
plt.savefig(current + plot_path + computer +"horse_race256_plain_log_y.pdf")

# %%
fig = plt.figure()
ax = fig.gca()

m_legend_horse_race = [name.split("_m")[0] for name in names]


for name in names:
    df = horse_race_m0_res[name]
    label = name.split("_m")[0]
    if label == "elementary_transposed":
        label = label.split("_")[1]
    elif label == "recursive_copying":
        label = label.split("_")[1]
    elif label == "recursive_write_through":
        label = label.split("_")[1] + "_" + label.split("_")[2]
    ax.plot(df['n'], df['time'], label=label, marker="o")

ax.set_yscale('log', base=2)
ax.set_xscale('log', base=2)
plt.xticks(n_ticks_horse, n_label_horse)


#outside for-loop
ax.set_xlabel("n")
ax.set_ylabel("log time(s)")
ax.legend()

#save plot as pdf
plt.savefig(current + plot_path + computer +"horse_race256_loglog.pdf")

# %%
fig = plt.figure()
ax = fig.gca()

for name in names:
    df = horse_race_m0_res[name]
    label = name.split("_m")[0]
    if label == "elementary_transposed":
        label = label.split("_")[1]
    elif label == "recursive_copying":
        label = label.split("_")[1]
    elif label == "recursive_write_through":
        label = label.split("_")[1] + "_" + label.split("_")[2]
    ax.plot(df['n'], df['nano_seconds/runtime'], label=label, marker="o")

ax.set_yscale('log', base=2)
ax.set_xscale('log', base=2)
plt.xticks(n_ticks_horse, n_label_horse)


#outside for-loop
ax.set_xlabel("n")
ax.set_ylabel("log time(nano sec/runtime)")
ax.legend(loc='lower left', bbox_to_anchor=(0.6,0.5))

#save plot as pdf
plt.savefig(current+plot_path+ computer + "horse_race256_runtime_scaled.pdf")

# %% [markdown]
# ## Tiled plots with fixed N = 256

# %%
s_ticks = [2,4,8,16,32,64,128]
n = 256

s_label = [str(tick) for tick in s_ticks]

# %%
tiled_path = "/experiments/results/tiled_experiment/"

name = "256n_tiled_multiplication_s_experiment.csv"

tiled_df = pd.read_csv(current + tiled_path +  name)

tiled_df['nano_seconds/runtime'] = tiled_df.apply(lambda x: (1000000000*x['time']) / n**3, axis=1)

print(tiled_df)
# Out:
#      s       time      stdv  nano_seconds/runtime
# 0    2  35.286822  0.263627           2103.258500
# 1    4  25.406195  0.004774           1514.327219
# 2    8  22.457708  0.027359           1338.583691
# 3   16  21.006982  0.028259           1252.113691
# 4   32  21.064733  0.052177           1255.555925
# 5   64  21.161859  0.075981           1261.345095
# 6  128  21.150426  0.082496           1260.663652

# %% [markdown]
# ### Generate latex table

# %%
print(tiled_df.to_latex())
# Out:
# \begin{tabular}{lrrrr}
# \toprule
# {} &    s &       time &      stdv &  nano\_seconds/runtime \\
# \midrule
# 0 &    2 &  35.286822 &  0.263627 &           2103.258500 \\
# 1 &    4 &  25.406195 &  0.004774 &           1514.327219 \\
# 2 &    8 &  22.457708 &  0.027359 &           1338.583691 \\
# 3 &   16 &  21.006982 &  0.028259 &           1252.113691 \\
# 4 &   32 &  21.064733 &  0.052177 &           1255.555925 \\
# 5 &   64 &  21.161859 &  0.075981 &           1261.345095 \\
# 6 &  128 &  21.150426 &  0.082496 &           1260.663652 \\
# \bottomrule
# \end{tabular}

# %%
fig = plt.figure()
ax = fig.gca()
ax.plot(tiled_df['s'], tiled_df['time'], label="n=256", marker = 'o')

ax.set_xscale('log', base=2)
plt.xticks(s_ticks, s_label)


ax.set_ylabel("time (s)")
ax.set_xlabel("s")

ax.legend()
plt.savefig(current+plot_path+ computer+"tiled_256_plain_time_x_log.pdf")

# %%
fig = plt.figure()
ax = fig.gca()
ax.plot(tiled_df['s'], tiled_df['time'], label="n=256", marker = 'o')
ax.set_yscale('log', base=2)
ax.set_xscale('log', base=2)
plt.xticks(s_ticks, s_label)


ax.set_ylabel("log time (s)")
ax.set_xlabel("s")

ax.legend()
plt.savefig(current+plot_path+ computer+"tiled_256_loglog.pdf")

# %%
fig = plt.figure()
ax = fig.gca()
ax.plot(tiled_df['s'], tiled_df['nano_seconds/runtime'], label="n=256", marker = 'o')
ax.set_xscale('log', base=2)
ax.set_yscale('log', base=2)
plt.xticks(s_ticks, s_label)

ax.set_ylabel("log time (nano s)")
ax.set_xlabel("s")

ax.legend()

print(ax.get_yticks())
plt.savefig(current+plot_path+ computer+"tiled_256_runtime_scaled.pdf")
# Out:
# [ 512. 1024. 2048. 4096. 8192.]

# %% [markdown]
# ## Plots for write_through with fixed n=256

# %%
m_ticks = [2,4,8,16,32,64,128]
n = 256

m_label = [str(tick) for tick in m_ticks]

write_through_path = "/experiments/results/write_through_m_experiments/"

name = "n256_recursive_write_through_n_fixed_mtest.csv"


write_through_df = pd.read_csv(current + write_through_path +  name)
write_through_df['nano_seconds/runtime'] = write_through_df.apply(lambda x: (1000000000*x['time(s)']) / n**3, axis=1)    

write_through_df["n as str"] = write_through_df.apply(lambda x: str(int(x['n'])), axis=1)

# %% [markdown]
# ### Generate latex table

# %%
print(write_through_df.to_latex(caption="Write_through algorithm for n=256 with different values of m"))
# Out:
# \begin{table}
# \centering
# \caption{Write_through algorithm for n=256 with different values of m}
# \begin{tabular}{lrrrrl}
# \toprule
# {} &    n &    time(s) &      stdv &  nano\_seconds/runtime & n as str \\
# \midrule
# 0 &    0 &  85.050945 &  0.570346 &           5069.431386 &        0 \\
# 1 &    2 &  17.109285 &  0.128721 &           1019.792876 &        2 \\
# 2 &    4 &   8.851750 &  0.067093 &            527.605389 &        4 \\
# 3 &    8 &   7.246603 &  0.039321 &            431.931217 &        8 \\
# 4 &   16 &   6.829965 &  0.067456 &            407.097649 &       16 \\
# 5 &   32 &   6.673965 &  0.006570 &            397.799312 &       32 \\
# 6 &   64 &   6.697631 &  0.042814 &            399.209938 &       64 \\
# 7 &  128 &   6.634563 &  0.020842 &            395.450778 &      128 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
fig = plt.figure()
ax = fig.gca()

ax.plot(write_through_df['n'], write_through_df['time(s)'], label="n=256", marker = 'o', color="green")
ax.set_yscale('log', base=2)
ax.set_xscale('log', base=2)
plt.xticks(m_ticks, m_label)

ax.set_ylabel("log time (s)")
ax.set_xlabel("m")
ax.legend()

plt.savefig(current+plot_path+computer+ "recursive_write_through_fixed_n_loglog.pdf")

# %%
plain_m_ticks = [0,2,4,8,16,32,64,128]
plain_m_label = [str(tick) for tick in plain_m_ticks]

fig = plt.figure()
ax = fig.gca()

ax.plot(write_through_df['n as str'], write_through_df['time(s)'], label="n=256", marker = 'o', color="green")
# ax.set_xscale('log', base=2)
# plt.xticks(plain_m_ticks, plain_m_label)

ax.set_ylabel("time (s)")
ax.set_xlabel("m")
ax.legend()
plt.savefig(current+plot_path+computer+ "recursive_write_through_fixed_n_plain.pdf")

# %%
fig = plt.figure()
ax = fig.gca()

ax.plot(write_through_df['n'], write_through_df['nano_seconds/runtime'], label="n=256", marker = 'o', color="green")

ax.set_yscale('log', base=2)
ax.set_xscale('log', base=2)
plt.xticks(m_ticks, m_label)

ax.set_ylabel("log time (nano s)")
ax.set_xlabel("m")
ax.legend()

#save plot as pdf
plt.savefig(current+plot_path+computer+ "recursive_write_through_fixed_n_runtime_scaled.pdf")

# %% [markdown]
# ## Plots for strassen with fixed n=256

# %%
strassen_path = "/experiments/results/strassen_m_experiments/"

name = "n256_strassen_n_fixed_mtest.csv"

strassen_df = pd.read_csv(current + strassen_path +  name)
strassen_df['nano_seconds/runtime'] = strassen_df.apply(lambda x: (1000000000*x['time(s)']) / n**2.8, axis=1)

strassen_df["m as str"] = strassen_df.apply(lambda x: str(int(x['n'])), axis=1)    


print(strassen_df)
# Out:
#      n    time(s)      stdv  nano_seconds/runtime m as str
# 0    0  50.291963  0.017154           9087.128834        0
# 1    2  12.671518  0.020420           2289.584876        2
# 2    4   4.802607  0.011825            867.771025        4
# 3    8   3.826228  0.010634            691.351636        8
# 4   16   3.862172  0.014518            697.846207       16
# 5   32   4.313387  0.019903            779.375063       32
# 6   64   4.935135  0.028239            891.717247       64
# 7  128   5.584180  0.021938           1008.991417      128

# %% [markdown]
# ### Generate table for latex

# %%
print(strassen_df.to_latex(caption="Strassen algorithm for n=256 with different values of m"))
# Out:
# \begin{table}
# \centering
# \caption{Strassen algorithm for n=256 with different values of m}
# \begin{tabular}{lrrrrl}
# \toprule
# {} &    n &    time(s) &      stdv &  nano\_seconds/runtime & m as str \\
# \midrule
# 0 &    0 &  50.291963 &  0.017154 &           9087.128834 &        0 \\
# 1 &    2 &  12.671518 &  0.020420 &           2289.584876 &        2 \\
# 2 &    4 &   4.802607 &  0.011825 &            867.771025 &        4 \\
# 3 &    8 &   3.826228 &  0.010634 &            691.351636 &        8 \\
# 4 &   16 &   3.862172 &  0.014518 &            697.846207 &       16 \\
# 5 &   32 &   4.313387 &  0.019903 &            779.375063 &       32 \\
# 6 &   64 &   4.935135 &  0.028239 &            891.717247 &       64 \\
# 7 &  128 &   5.584180 &  0.021938 &           1008.991417 &      128 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
fig = plt.figure()
ax = fig.gca()


ax.plot(strassen_df["m as str"], strassen_df['time(s)'], label="n=256", marker = 'o', color="red")
ax.set_ylabel("time (s)")

# ax.set_yscale('log', base=2)
# plt.xticks(m_ticks, m_label)

ax.set_xlabel("m")
ax.legend()

#save plot as pdf
plt.savefig(current+plot_path+computer+ "strassen_fixed_n256_plain.pdf")

# %%
fig = plt.figure()
ax = fig.gca()

ax.plot(strassen_df['n'], strassen_df['time(s)'], label="n=256", marker = 'o', color="red")

ax.set_yscale('log', base=2)
ax.set_xscale('log', base=2)
plt.xticks(m_ticks, m_label)

ax.set_ylabel("log time (s)")
ax.set_xlabel("m")
ax.legend()

#save plot as pdf
plt.savefig(current+plot_path+computer+ "strassen_fixed_n256_loglog.pdf")

# %%
fig = plt.figure()
ax = fig.gca()

ax.plot(strassen_df['n'], strassen_df['nano_seconds/runtime'], label="n=256", marker = 'o', color="red")

ax.set_yscale('log', base=2)
ax.set_xscale('log', base=2)
plt.xticks(m_ticks, m_label)

#outside for-loop
ax.set_ylabel("log time (nano s)")
ax.set_xlabel("m")
ax.legend()

#save plot as pdf
plt.savefig(current+plot_path+computer+ "strassen_fixed_n256_runtime_scaled.pdf")

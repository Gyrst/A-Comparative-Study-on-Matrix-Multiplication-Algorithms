# %% [markdown]
# # Tests on Extreme Inputs
#
# The following test section has the purpose is comprising tests that we expect to fail. This comprise tests that will show the limitation when working with floating point numbers. In particular this relates to testing for input values (x) in our matrices that exceed our limit of x < sqrt(2**53/n). This test does not include test on small numbers but we would expect same behavior with a set of very small numbers, as that ultimately also could result in rounding error. Namely numbers between 0.0-1.0 that include decimals beyond what we expect for floating point accuracy.
#
# #### 1) Test on Large Numbers: x > sqrt(2**53/n)
#
# All tests are run with: numpy.assert_equals() numpy.assert_allclose() https://numpy.org/doc/stable/reference/generated/numpy.allclose.html

# %%
import sys
import os
  
# getting the name of the directory
# where the this file is present.
current = os.path.abspath('')
# Getting the parent directory name
# where the current directory is present.
parent = os.path.dirname(current)
sys.path.append(parent)
from parameters import *

from experiments import *
from matrix_implementations import *
import random
import numpy as np
import csv
import logging

# %% [markdown]
# ### Correct Input Generator (Following x < np.sqrt(2**(53)/n))

# %%
def get_input_range(n):
    lower_bound = 0
    upper_bound = round(np.sqrt(float(2**(53))/n))
    input_range = [lower_bound, upper_bound]
    return input_range


def generate_input(n: int) -> np.ndarray:
    list= []
    input_range = get_input_range(n)
    for i in range(0,n*n):
        l = random.randint(input_range[0],int(input_range[1]))
        list.append(float(l))
    return np.array(list).reshape(n,n)

# %% [markdown]
# ### Too Large Inputs

# %%
def too_large_input_range(n, power):
    lower_bound = 0
    upper_bound = round(np.sqrt(float(2**(power)/n)))
    input_range = [lower_bound, upper_bound]
    return input_range

def generate_too_large_input(n, power=70):
    list= []
    input_range = too_large_input_range(n, power)
    for i in range(0,n*n):
        
        l = random.randint(input_range[0],int(input_range[1]))
        list.append(float(l))
    return np.array(list).reshape(n,n)

# %% [markdown]
# ### Test Matrix Generation

# %%
n = 64
A = generate_too_large_input(n)
B = generate_too_large_input(n)
C = generate_too_large_input(n)

# %%
A_within = generate_input(n)
B_within = generate_input(n)
type(A)
# Out:
# numpy.ndarray

# %% [markdown]
# # Quick tests to with some basic inputs
#
# Further down there is full test method for extended tests: Go check them out!

# %%
np_res = np.matmul(A,B)
res = elementary_multiplication(Matrix(n,n, A), Matrix(n,n,B))

# %%
np_res_within = np.matmul(A_within,B_within)
res_within = elementary_multiplication(Matrix(n,n, A_within), Matrix(n,n,B_within))

# %%
#np.testing.assert_allclose(res.tolist(), np_res, 0.01, 0.05)

# %%
np.testing.assert_array_equal(res_within.tolist(),np_res_within)

# %%
#np.testing.assert_equal(res.tolist(), np_res)

# %%
def test(algorithm, A:np.ndarray, B:np.ndarray, n:int, C:Matrix=None):
    try:
        if C == None:
            np.testing.assert_equal(algorithm(Matrix(len(A),len(A), A), Matrix(len(B),len(B),B)).tolist(), np.matmul(A,B))
            print("Ok")
        else:
            np.testing.assert_equal(algorithm(Matrix(len(A),len(A), A), Matrix(len(B),len(B),B), C).tolist(), np.matmul(A,B))
            print("Ok")
    except AssertionError as error:
        
        # Uncomment the log to see full error message each time
        logging.error("TEXT", exc_info=True)
        error_message = str(error)
        error_percentage = float(error_message.split("Mismatched elements: ")[1].split("%)")[0].split("(")[1])/100
        
        return error_percentage

#test(elementary_multiplication, A, B, n)

# %%
def full_test(algorithm_to_be_tested, input_generator, n:int, iterations:int, inplace=False, power:int=None):
    
    """full_test takes an algorithm that is to be tested and the specified input generator that creates the inputs for 
    the given test. It evaluates whether a power is specified. Here a power refers to the power to which the input is
    scaled with. it also checks if the algorithm being tested is an inplace algorithm or copying variant.
    
    """
    errors = []
    
    for i in range(iterations):
        
        if power != None:
            A = input_generator(n, power)
            B = input_generator(n, power)
        else: 
            A = input_generator(n)
            B = input_generator(n)
            
        if inplace == True:     
            val = test(algorithm_to_be_tested, A, B, C=Matrix(len(A),len(A)), n=n)
            if val != None:
                errors.append(val)
        else:
            val = test(algorithm_to_be_tested, A, B, n=n)
            if val != None:
                errors.append(val)
    
    return errors

# %% [markdown]
# ### The Real Testing - Try out the methods and run some tests
#
# The tests below uses the methods provided above to test on very large inputs. Here we in particular reveal how strassen's algorithm with the more arithmetic operations

# %%
#Basic test on the recursive write through:
#writes ok for each test and returns an empty list if there are no mistakes in the test
full_test(recursive_multiplication_write_through, generate_input, n, iterations=3, inplace=True)
# Out:
# Ok
# Ok
# Ok
# []

# %% [markdown]
# ### Strassen Failing on large inputs earlier than other methods

# %%
powers = [47,50,53,56,59,62,65,68,71,74,77]
res = {}

print("Please don't mind the Error log text. It can be # commented out in the test method if desired.")

for power in powers:
    temp = full_test(strassen, generate_too_large_input,n, iterations=3, inplace=False, power=power)
    total = 0
    if len(temp) != 0:
        for x in temp:
            total += x
        average = total/len(temp)
        res[power] = average
    else:
        res[power] = "No failed computations"
# Out:
# Please don't mind the Error log text. It can be # commented out in the test method if desired.
# Ok
# Ok
# Ok
# ERROR:root:TEXT
# Traceback (most recent call last):
#   File "/tmp/ipykernel_12857/2947564240.py", line 4, in test
#     np.testing.assert_equal(algorithm(Matrix(len(A),len(A), A), Matrix(len(B),len(B),B)).tolist(), np.matmul(A,B))
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 345, in assert_equal
#     return assert_array_equal(actual, desired, err_msg, verbose)
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 935, in assert_array_equal
#     verbose=verbose, header='Arrays are not equal')
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 844, in assert_array_compare
#     raise AssertionError(msg)
# AssertionError:
# Arrays are not equal
#
# Mismatched elements: 156 / 4096 (3.81%)
# Max absolute difference: 2.
# Max relative difference: 8.36240556e-15
#  x: array([[2.892727e+14, 3.322558e+14, 2.877808e+14, ..., 2.842317e+14,
#         3.312153e+14, 3.497291e+14],
#        [2.910694e+14, 3.014186e+14, 2.866516e+14, ..., 2.754303e+14,...
#  y: array([[2.892727e+14, 3.322558e+14, 2.877808e+14, ..., 2.842317e+14,
#         3.312153e+14, 3.497291e+14],
#        [2.910694e+14, 3.014186e+14, 2.866516e+14, ..., 2.754303e+14,...
# ERROR:root:TEXT
# Traceback (most recent call last):
#   File "/tmp/ipykernel_12857/2947564240.py", line 4, in test
#     np.testing.assert_equal(algorithm(Matrix(len(A),len(A), A), Matrix(len(B),len(B),B)).tolist(), np.matmul(A,B))
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 345, in assert_equal
#     return assert_array_equal(actual, desired, err_msg, verbose)
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 935, in assert_array_equal
#     verbose=verbose, header='Arrays are not equal')
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 844, in assert_array_compare
#     raise AssertionError(msg)
# AssertionError:
# Arrays are not equal
#
# Mismatched elements: 96 / 4096 (2.34%)
# Max absolute difference: 2.
# Max relative difference: 8.83510035e-15
#  x: array([[2.476797e+14, 2.428918e+14, 2.436326e+14, ..., 2.552090e+14,
#         2.969138e+14, 2.778550e+14],
#        [2.574676e+14, 2.571839e+14, 2.485414e+14, ..., 2.844492e+14,...
#  y: array([[2.476797e+14, 2.428918e+14, 2.436326e+14, ..., 2.552090e+14,
#         2.969138e+14, 2.778550e+14],
#        [2.574676e+14, 2.571839e+14, 2.485414e+14, ..., 2.844492e+14,...
# ERROR:root:TEXT
# Traceback (most recent call last):
#   File "/tmp/ipykernel_12857/2947564240.py", line 4, in test
#     np.testing.assert_equal(algorithm(Matrix(len(A),len(A), A), Matrix(len(B),len(B),B)).tolist(), np.matmul(A,B))
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 345, in assert_equal
#     return assert_array_equal(actual, desired, err_msg, verbose)
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 935, in assert_array_equal
#     verbose=verbose, header='Arrays are not equal')
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 844, in assert_array_compare
#     raise AssertionError(msg)
# AssertionError:
# Arrays are not equal
#
# Mismatched elements: 64 / 4096 (1.56%)
# Max absolute difference: 2.
# Max relative difference: 9.16895099e-15
#  x: array([[2.783823e+14, 3.175220e+14, 3.002839e+14, ..., 2.400487e+14,
#         3.079607e+14, 3.094014e+14],
#        [2.838838e+14, 3.396236e+14, 2.932755e+14, ..., 2.541417e+14,...
#  y: array([[2.783823e+14, 3.175220e+14, 3.002839e+14, ..., 2.400487e+14,
#         3.079607e+14, 3.094014e+14],
#        [2.838838e+14, 3.396236e+14, 2.932755e+14, ..., 2.541417e+14,...
# ERROR:root:TEXT
# Traceback (most recent call last):
#   File "/tmp/ipykernel_12857/2947564240.py", line 4, in test
#     np.testing.assert_equal(algorithm(Matrix(len(A),len(A), A), Matrix(len(B),len(B),B)).tolist(), np.matmul(A,B))
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 345, in assert_equal
#     return assert_array_equal(actual, desired, err_msg, verbose)
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 935, in assert_array_equal
#     verbose=verbose, header='Arrays are not equal')
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 844, in assert_array_compare
#     raise AssertionError(msg)
# AssertionError:
# Arrays are not equal
#
# Mismatched elements: 2393 / 4096 (58.4%)
# Max absolute difference: 38.
# Max relative difference: 1.65374841e-14
#  x: array([[2.249980e+15, 2.165858e+15, 2.172086e+15, ..., 2.077631e+15,
#         2.317506e+15, 2.322115e+15],
#        [1.973151e+15, 2.177282e+15, 2.206766e+15, ..., 1.969322e+15,...
#  y: array([[2.249980e+15, 2.165858e+15, 2.172086e+15, ..., 2.077631e+15,
#         2.317506e+15, 2.322115e+15],
#        [1.973151e+15, 2.177282e+15, 2.206766e+15, ..., 1.969322e+15,...
# ERROR:root:TEXT
# Traceback (most recent call last):
#   File "/tmp/ipykernel_12857/2947564240.py", line 4, in test
#     np.testing.assert_equal(algorithm(Matrix(len(A),len(A), A), Matrix(len(B),len(B),B)).tolist(), np.matmul(A,B))
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 345, in assert_equal
#     return assert_array_equal(actual, desired, err_msg, verbose)
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 935, in assert_array_equal
#     verbose=verbose, header='Arrays are not equal')
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 844, in assert_array_compare
#     raise AssertionError(msg)
# AssertionError:
# Arrays are not equal
#
# Mismatched elements: 2542 / 4096 (62.1%)
# Max absolute difference: 25.
# Max relative difference: 1.13581003e-14
#  x: array([[2.563970e+15, 2.069972e+15, 2.279335e+15, ..., 2.208901e+15,
#         2.355051e+15, 2.320664e+15],
#        [2.241902e+15, 1.783774e+15, 1.770241e+15, ..., 1.829004e+15,...
#  y: array([[2.563970e+15, 2.069972e+15, 2.279335e+15, ..., 2.208901e+15,
#         2.355051e+15, 2.320664e+15],
#        [2.241902e+15, 1.783774e+15, 1.770241e+15, ..., 1.829004e+15,...
# ERROR:root:TEXT
# Traceback (most recent call last):
#   File "/tmp/ipykernel_12857/2947564240.py", line 4, in test
#     np.testing.assert_equal(algorithm(Matrix(len(A),len(A), A), Matrix(len(B),len(B),B)).tolist(), np.matmul(A,B))
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 345, in assert_equal
#     return assert_array_equal(actual, desired, err_msg, verbose)
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 935, in assert_array_equal
#     verbose=verbose, header='Arrays are not equal')
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 844, in assert_array_compare
#     raise AssertionError(msg)
# AssertionError:
# Arrays are not equal
#
# Mismatched elements: 2523 / 4096 (61.6%)
# Max absolute difference: 46.
# Max relative difference: 2.16755909e-14
#  x: array([[2.345492e+15, 2.722548e+15, 2.639360e+15, ..., 3.096008e+15,
#         2.828255e+15, 2.704498e+15],
#        [2.102974e+15, 2.443116e+15, 2.232054e+15, ..., 2.525772e+15,...
#  y: array([[2.345492e+15, 2.722548e+15, 2.639360e+15, ..., 3.096008e+15,
#         2.828255e+15, 2.704498e+15],
#        [2.102974e+15, 2.443116e+15, 2.232054e+15, ..., 2.525772e+15,...
# ERROR:root:TEXT
# Traceback (most recent call last):
#   File "/tmp/ipykernel_12857/2947564240.py", line 4, in test
#     np.testing.assert_equal(algorithm(Matrix(len(A),len(A), A), Matrix(len(B),len(B),B)).tolist(), np.matmul(A,B))
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 345, in assert_equal
#     return assert_array_equal(actual, desired, err_msg, verbose)
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 935, in assert_array_equal
#     verbose=verbose, header='Arrays are not equal')
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 844, in assert_array_compare
#     raise AssertionError(msg)
# AssertionError:
# Arrays are not equal
#
# Mismatched elements: 3707 / 4096 (90.5%)
# Max absolute difference: 546.
# Max relative difference: 3.09327128e-14
#  x: array([[1.546181e+16, 1.866677e+16, 1.688549e+16, ..., 1.672756e+16,
#         1.568160e+16, 1.747078e+16],
#        [1.580336e+16, 2.028361e+16, 1.827699e+16, ..., 1.753922e+16,...
#  y: array([[1.546181e+16, 1.866677e+16, 1.688549e+16, ..., 1.672756e+16,
#         1.568160e+16, 1.747078e+16],
#        [1.580336e+16, 2.028361e+16, 1.827699e+16, ..., 1.753922e+16,...
# ERROR:root:TEXT
# Traceback (most recent call last):
#   File "/tmp/ipykernel_12857/2947564240.py", line 4, in test
#     np.testing.assert_equal(algorithm(Matrix(len(A),len(A), A), Matrix(len(B),len(B),B)).tolist(), np.matmul(A,B))
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 345, in assert_equal
#     return assert_array_equal(actual, desired, err_msg, verbose)
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 935, in assert_array_equal
#     verbose=verbose, header='Arrays are not equal')
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 844, in assert_array_compare
#     raise AssertionError(msg)
# AssertionError:
# Arrays are not equal
#
# Mismatched elements: 3722 / 4096 (90.9%)
# Max absolute difference: 464.
# Max relative difference: 3.03453241e-14
#  x: array([[1.840939e+16, 1.686497e+16, 1.786077e+16, ..., 1.958395e+16,
#         1.507712e+16, 1.629814e+16],
#        [1.986907e+16, 1.528187e+16, 1.766573e+16, ..., 1.963379e+16,...
#  y: array([[1.840939e+16, 1.686497e+16, 1.786077e+16, ..., 1.958395e+16,
#         1.507712e+16, 1.629814e+16],
#        [1.986907e+16, 1.528187e+16, 1.766573e+16, ..., 1.963379e+16,...
# ERROR:root:TEXT
# Traceback (most recent call last):
#   File "/tmp/ipykernel_12857/2947564240.py", line 4, in test
#     np.testing.assert_equal(algorithm(Matrix(len(A),len(A), A), Matrix(len(B),len(B),B)).tolist(), np.matmul(A,B))
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 345, in assert_equal
#     return assert_array_equal(actual, desired, err_msg, verbose)
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 935, in assert_array_equal
#     verbose=verbose, header='Arrays are not equal')
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 844, in assert_array_compare
#     raise AssertionError(msg)
# AssertionError:
# Arrays are not equal
#
# Mismatched elements: 3748 / 4096 (91.5%)
# Max absolute difference: 384.
# Max relative difference: 2.3841985e-14
#  x: array([[1.551875e+16, 1.410377e+16, 1.348336e+16, ..., 1.619421e+16,
#         1.357649e+16, 1.542011e+16],
#        [1.644716e+16, 1.728461e+16, 1.648916e+16, ..., 1.721852e+16,...
#  y: array([[1.551875e+16, 1.410377e+16, 1.348336e+16, ..., 1.619421e+16,
#         1.357649e+16, 1.542011e+16],
#        [1.644716e+16, 1.728461e+16, 1.648916e+16, ..., 1.721852e+16,...
# ERROR:root:TEXT
# Traceback (most recent call last):
#   File "/tmp/ipykernel_12857/2947564240.py", line 4, in test
#     np.testing.assert_equal(algorithm(Matrix(len(A),len(A), A), Matrix(len(B),len(B),B)).tolist(), np.matmul(A,B))
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 345, in assert_equal
#     return assert_array_equal(actual, desired, err_msg, verbose)
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 935, in assert_array_equal
#     verbose=verbose, header='Arrays are not equal')
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 844, in assert_array_compare
#     raise AssertionError(msg)
# AssertionError:
# Arrays are not equal
#
# Mismatched elements: 3753 / 4096 (91.6%)
# Max absolute difference: 2480.
# Max relative difference: 1.75336585e-14
#  x: array([[1.676066e+17, 1.491102e+17, 1.516003e+17, ..., 1.159321e+17,
#         1.258887e+17, 1.396544e+17],
#        [1.658708e+17, 1.465419e+17, 1.655388e+17, ..., 1.250381e+17,...
#  y: array([[1.676066e+17, 1.491102e+17, 1.516003e+17, ..., 1.159321e+17,
#         1.258887e+17, 1.396544e+17],
#        [1.658708e+17, 1.465419e+17, 1.655388e+17, ..., 1.250381e+17,...
# ERROR:root:TEXT
# Traceback (most recent call last):
#   File "/tmp/ipykernel_12857/2947564240.py", line 4, in test
#     np.testing.assert_equal(algorithm(Matrix(len(A),len(A), A), Matrix(len(B),len(B),B)).tolist(), np.matmul(A,B))
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 345, in assert_equal
#     return assert_array_equal(actual, desired, err_msg, verbose)
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 935, in assert_array_equal
#     verbose=verbose, header='Arrays are not equal')
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 844, in assert_array_compare
#     raise AssertionError(msg)
# AssertionError:
# Arrays are not equal
#
# Mismatched elements: 3731 / 4096 (91.1%)
# Max absolute difference: 2432.
# Max relative difference: 1.62316813e-14
#  x: array([[1.758416e+17, 1.679725e+17, 1.774296e+17, ..., 1.729782e+17,
#         1.753364e+17, 1.967796e+17],
#        [1.773375e+17, 1.701078e+17, 1.657626e+17, ..., 1.750508e+17,...
#  y: array([[1.758416e+17, 1.679725e+17, 1.774296e+17, ..., 1.729782e+17,
#         1.753364e+17, 1.967796e+17],
#        [1.773375e+17, 1.701078e+17, 1.657626e+17, ..., 1.750508e+17,...
# ERROR:root:TEXT
# Traceback (most recent call last):
#   File "/tmp/ipykernel_12857/2947564240.py", line 4, in test
#     np.testing.assert_equal(algorithm(Matrix(len(A),len(A), A), Matrix(len(B),len(B),B)).tolist(), np.matmul(A,B))
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 345, in assert_equal
#     return assert_array_equal(actual, desired, err_msg, verbose)
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 935, in assert_array_equal
#     verbose=verbose, header='Arrays are not equal')
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 844, in assert_array_compare
#     raise AssertionError(msg)
# AssertionError:
# Arrays are not equal
#
# Mismatched elements: 3772 / 4096 (92.1%)
# Max absolute difference: 2848.
# Max relative difference: 1.85816872e-14
#  x: array([[1.176633e+17, 1.221922e+17, 1.076463e+17, ..., 1.470727e+17,
#         1.170746e+17, 1.468637e+17],
#        [1.547926e+17, 1.547012e+17, 1.418336e+17, ..., 1.695674e+17,...
#  y: array([[1.176633e+17, 1.221922e+17, 1.076463e+17, ..., 1.470727e+17,
#         1.170746e+17, 1.468637e+17],
#        [1.547926e+17, 1.547012e+17, 1.418336e+17, ..., 1.695674e+17,...
# ERROR:root:TEXT
# Traceback (most recent call last):
#   File "/tmp/ipykernel_12857/2947564240.py", line 4, in test
#     np.testing.assert_equal(algorithm(Matrix(len(A),len(A), A), Matrix(len(B),len(B),B)).tolist(), np.matmul(A,B))
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 345, in assert_equal
#     return assert_array_equal(actual, desired, err_msg, verbose)
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 935, in assert_array_equal
#     verbose=verbose, header='Arrays are not equal')
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 844, in assert_array_compare
#     raise AssertionError(msg)
# AssertionError:
# Arrays are not equal
#
# Mismatched elements: 3777 / 4096 (92.2%)
# Max absolute difference: 19200.
# Max relative difference: 1.73294025e-14
#  x: array([[1.311207e+18, 1.067476e+18, 1.398548e+18, ..., 1.186558e+18,
#         1.261258e+18, 1.297946e+18],
#        [1.252832e+18, 1.152804e+18, 1.384920e+18, ..., 1.216210e+18,...
#  y: array([[1.311207e+18, 1.067476e+18, 1.398548e+18, ..., 1.186558e+18,
#         1.261258e+18, 1.297946e+18],
#        [1.252832e+18, 1.152804e+18, 1.384920e+18, ..., 1.216210e+18,...
# ERROR:root:TEXT
# Traceback (most recent call last):
#   File "/tmp/ipykernel_12857/2947564240.py", line 4, in test
#     np.testing.assert_equal(algorithm(Matrix(len(A),len(A), A), Matrix(len(B),len(B),B)).tolist(), np.matmul(A,B))
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 345, in assert_equal
#     return assert_array_equal(actual, desired, err_msg, verbose)
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 935, in assert_array_equal
#     verbose=verbose, header='Arrays are not equal')
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 844, in assert_array_compare
#     raise AssertionError(msg)
# AssertionError:
# Arrays are not equal
#
# Mismatched elements: 3769 / 4096 (92%)
# Max absolute difference: 30080.
# Max relative difference: 2.86430161e-14
#  x: array([[1.131088e+18, 1.069663e+18, 1.085769e+18, ..., 1.097857e+18,
#         1.235694e+18, 1.206745e+18],
#        [1.045519e+18, 9.958683e+17, 9.758172e+17, ..., 1.095006e+18,...
#  y: array([[1.131088e+18, 1.069663e+18, 1.085769e+18, ..., 1.097857e+18,
#         1.235694e+18, 1.206745e+18],
#        [1.045519e+18, 9.958683e+17, 9.758172e+17, ..., 1.095006e+18,...
# ERROR:root:TEXT
# Traceback (most recent call last):
#   File "/tmp/ipykernel_12857/2947564240.py", line 4, in test
#     np.testing.assert_equal(algorithm(Matrix(len(A),len(A), A), Matrix(len(B),len(B),B)).tolist(), np.matmul(A,B))
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 345, in assert_equal
#     return assert_array_equal(actual, desired, err_msg, verbose)
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 935, in assert_array_equal
#     verbose=verbose, header='Arrays are not equal')
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 844, in assert_array_compare
#     raise AssertionError(msg)
# AssertionError:
# Arrays are not equal
#
# Mismatched elements: 3766 / 4096 (91.9%)
# Max absolute difference: 23040.
# Max relative difference: 2.02989737e-14
#  x: array([[1.405570e+18, 1.300209e+18, 1.677489e+18, ..., 1.324010e+18,
#         1.322810e+18, 1.526540e+18],
#        [1.308214e+18, 1.162094e+18, 1.495372e+18, ..., 1.226751e+18,...
#  y: array([[1.405570e+18, 1.300209e+18, 1.677489e+18, ..., 1.324010e+18,
#         1.322810e+18, 1.526540e+18],
#        [1.308214e+18, 1.162094e+18, 1.495372e+18, ..., 1.226751e+18,...
# ERROR:root:TEXT
# Traceback (most recent call last):
#   File "/tmp/ipykernel_12857/2947564240.py", line 4, in test
#     np.testing.assert_equal(algorithm(Matrix(len(A),len(A), A), Matrix(len(B),len(B),B)).tolist(), np.matmul(A,B))
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 345, in assert_equal
#     return assert_array_equal(actual, desired, err_msg, verbose)
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 935, in assert_array_equal
#     verbose=verbose, header='Arrays are not equal')
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 844, in assert_array_compare
#     raise AssertionError(msg)
# AssertionError:
# Arrays are not equal
#
# Mismatched elements: 3786 / 4096 (92.4%)
# Max absolute difference: 137216.
# Max relative difference: 1.45982408e-14
#  x: array([[1.017977e+19, 9.184479e+18, 1.033807e+19, ..., 7.572145e+18,
#         8.127908e+18, 9.759078e+18],
#        [9.671386e+18, 1.006313e+19, 1.006480e+19, ..., 7.941843e+18,...
#  y: array([[1.017977e+19, 9.184479e+18, 1.033807e+19, ..., 7.572145e+18,
#         8.127908e+18, 9.759078e+18],
#        [9.671386e+18, 1.006313e+19, 1.006480e+19, ..., 7.941843e+18,...
# ERROR:root:TEXT
# Traceback (most recent call last):
#   File "/tmp/ipykernel_12857/2947564240.py", line 4, in test
#     np.testing.assert_equal(algorithm(Matrix(len(A),len(A), A), Matrix(len(B),len(B),B)).tolist(), np.matmul(A,B))
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 345, in assert_equal
#     return assert_array_equal(actual, desired, err_msg, verbose)
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 935, in assert_array_equal
#     verbose=verbose, header='Arrays are not equal')
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 844, in assert_array_compare
#     raise AssertionError(msg)
# AssertionError:
# Arrays are not equal
#
# Mismatched elements: 3828 / 4096 (93.5%)
# Max absolute difference: 194560.
# Max relative difference: 2.77249211e-14
#  x: array([[1.050099e+19, 9.940421e+18, 1.135348e+19, ..., 1.070400e+19,
#         9.438164e+18, 9.445243e+18],
#        [1.001135e+19, 9.674004e+18, 1.101805e+19, ..., 9.627516e+18,...
#  y: array([[1.050099e+19, 9.940421e+18, 1.135348e+19, ..., 1.070400e+19,
#         9.438164e+18, 9.445243e+18],
#        [1.001135e+19, 9.674004e+18, 1.101805e+19, ..., 9.627516e+18,...
# ERROR:root:TEXT
# Traceback (most recent call last):
#   File "/tmp/ipykernel_12857/2947564240.py", line 4, in test
#     np.testing.assert_equal(algorithm(Matrix(len(A),len(A), A), Matrix(len(B),len(B),B)).tolist(), np.matmul(A,B))
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 345, in assert_equal
#     return assert_array_equal(actual, desired, err_msg, verbose)
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 935, in assert_array_equal
#     verbose=verbose, header='Arrays are not equal')
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 844, in assert_array_compare
#     raise AssertionError(msg)
# AssertionError:
# Arrays are not equal
#
# Mismatched elements: 3780 / 4096 (92.3%)
# Max absolute difference: 194560.
# Max relative difference: 2.1652228e-14
#  x: array([[9.678811e+18, 8.142497e+18, 6.982004e+18, ..., 8.587760e+18,
#         8.216785e+18, 1.054550e+19],
#        [1.004830e+19, 9.246459e+18, 7.712234e+18, ..., 8.798180e+18,...
#  y: array([[9.678811e+18, 8.142497e+18, 6.982004e+18, ..., 8.587760e+18,
#         8.216785e+18, 1.054550e+19],
#        [1.004830e+19, 9.246459e+18, 7.712234e+18, ..., 8.798180e+18,...
# ERROR:root:TEXT
# Traceback (most recent call last):
#   File "/tmp/ipykernel_12857/2947564240.py", line 4, in test
#     np.testing.assert_equal(algorithm(Matrix(len(A),len(A), A), Matrix(len(B),len(B),B)).tolist(), np.matmul(A,B))
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 345, in assert_equal
#     return assert_array_equal(actual, desired, err_msg, verbose)
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 935, in assert_array_equal
#     verbose=verbose, header='Arrays are not equal')
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 844, in assert_array_compare
#     raise AssertionError(msg)
# AssertionError:
# Arrays are not equal
#
# Mismatched elements: 3807 / 4096 (92.9%)
# Max absolute difference: 2056192.
# Max relative difference: 3.16552878e-14
#  x: array([[5.494721e+19, 6.988692e+19, 6.797479e+19, ..., 6.191830e+19,
#         7.224273e+19, 6.643612e+19],
#        [6.539932e+19, 8.012712e+19, 7.652284e+19, ..., 7.868606e+19,...
#  y: array([[5.494721e+19, 6.988692e+19, 6.797479e+19, ..., 6.191830e+19,
#         7.224273e+19, 6.643612e+19],
#        [6.539932e+19, 8.012712e+19, 7.652284e+19, ..., 7.868606e+19,...
# ERROR:root:TEXT
# Traceback (most recent call last):
#   File "/tmp/ipykernel_12857/2947564240.py", line 4, in test
#     np.testing.assert_equal(algorithm(Matrix(len(A),len(A), A), Matrix(len(B),len(B),B)).tolist(), np.matmul(A,B))
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 345, in assert_equal
#     return assert_array_equal(actual, desired, err_msg, verbose)
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 935, in assert_array_equal
#     verbose=verbose, header='Arrays are not equal')
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 844, in assert_array_compare
#     raise AssertionError(msg)
# AssertionError:
# Arrays are not equal
#
# Mismatched elements: 3797 / 4096 (92.7%)
# Max absolute difference: 1540096.
# Max relative difference: 2.19940859e-14
#  x: array([[6.623820e+19, 7.733549e+19, 6.721780e+19, ..., 7.530732e+19,
#         7.334694e+19, 6.761359e+19],
#        [5.797035e+19, 6.845927e+19, 5.426429e+19, ..., 6.074001e+19,...
#  y: array([[6.623820e+19, 7.733549e+19, 6.721780e+19, ..., 7.530732e+19,
#         7.334694e+19, 6.761359e+19],
#        [5.797035e+19, 6.845927e+19, 5.426429e+19, ..., 6.074001e+19,...
# ERROR:root:TEXT
# Traceback (most recent call last):
#   File "/tmp/ipykernel_12857/2947564240.py", line 4, in test
#     np.testing.assert_equal(algorithm(Matrix(len(A),len(A), A), Matrix(len(B),len(B),B)).tolist(), np.matmul(A,B))
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 345, in assert_equal
#     return assert_array_equal(actual, desired, err_msg, verbose)
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 935, in assert_array_equal
#     verbose=verbose, header='Arrays are not equal')
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 844, in assert_array_compare
#     raise AssertionError(msg)
# AssertionError:
# Arrays are not equal
#
# Mismatched elements: 3779 / 4096 (92.3%)
# Max absolute difference: 1589248.
# Max relative difference: 2.00269903e-14
#  x: array([[8.474836e+19, 6.530740e+19, 9.668205e+19, ..., 7.416048e+19,
#         8.064416e+19, 7.325460e+19],
#        [7.348517e+19, 6.690074e+19, 9.046486e+19, ..., 7.454940e+19,...
#  y: array([[8.474836e+19, 6.530740e+19, 9.668205e+19, ..., 7.416048e+19,
#         8.064416e+19, 7.325460e+19],
#        [7.348517e+19, 6.690074e+19, 9.046486e+19, ..., 7.454940e+19,...
# ERROR:root:TEXT
# Traceback (most recent call last):
#   File "/tmp/ipykernel_12857/2947564240.py", line 4, in test
#     np.testing.assert_equal(algorithm(Matrix(len(A),len(A), A), Matrix(len(B),len(B),B)).tolist(), np.matmul(A,B))
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 345, in assert_equal
#     return assert_array_equal(actual, desired, err_msg, verbose)
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 935, in assert_array_equal
#     verbose=verbose, header='Arrays are not equal')
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 844, in assert_array_compare
#     raise AssertionError(msg)
# AssertionError:
# Arrays are not equal
#
# Mismatched elements: 3781 / 4096 (92.3%)
# Max absolute difference: 13500416.
# Max relative difference: 2.29263302e-14
#  x: array([[5.888608e+20, 7.162717e+20, 7.341990e+20, ..., 5.629420e+20,
#         6.269759e+20, 6.796404e+20],
#        [6.182949e+20, 7.227794e+20, 7.492278e+20, ..., 5.645981e+20,...
#  y: array([[5.888608e+20, 7.162717e+20, 7.341990e+20, ..., 5.629420e+20,
#         6.269759e+20, 6.796404e+20],
#        [6.182949e+20, 7.227794e+20, 7.492278e+20, ..., 5.645981e+20,...
# ERROR:root:TEXT
# Traceback (most recent call last):
#   File "/tmp/ipykernel_12857/2947564240.py", line 4, in test
#     np.testing.assert_equal(algorithm(Matrix(len(A),len(A), A), Matrix(len(B),len(B),B)).tolist(), np.matmul(A,B))
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 345, in assert_equal
#     return assert_array_equal(actual, desired, err_msg, verbose)
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 935, in assert_array_equal
#     verbose=verbose, header='Arrays are not equal')
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 844, in assert_array_compare
#     raise AssertionError(msg)
# AssertionError:
# Arrays are not equal
#
# Mismatched elements: 3782 / 4096 (92.3%)
# Max absolute difference: 12713984.
# Max relative difference: 2.16332695e-14
#  x: array([[5.178631e+20, 6.164145e+20, 5.852605e+20, ..., 5.401874e+20,
#         5.808236e+20, 6.108322e+20],
#        [5.232305e+20, 6.409986e+20, 6.468610e+20, ..., 5.456296e+20,...
#  y: array([[5.178631e+20, 6.164145e+20, 5.852605e+20, ..., 5.401874e+20,
#         5.808236e+20, 6.108322e+20],
#        [5.232305e+20, 6.409986e+20, 6.468610e+20, ..., 5.456296e+20,...
# ERROR:root:TEXT
# Traceback (most recent call last):
#   File "/tmp/ipykernel_12857/2947564240.py", line 4, in test
#     np.testing.assert_equal(algorithm(Matrix(len(A),len(A), A), Matrix(len(B),len(B),B)).tolist(), np.matmul(A,B))
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 345, in assert_equal
#     return assert_array_equal(actual, desired, err_msg, verbose)
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 935, in assert_array_equal
#     verbose=verbose, header='Arrays are not equal')
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 844, in assert_array_compare
#     raise AssertionError(msg)
# AssertionError:
# Arrays are not equal
#
# Mismatched elements: 3785 / 4096 (92.4%)
# Max absolute difference: 12976128.
# Max relative difference: 2.24253875e-14
#  x: array([[6.234524e+20, 6.193407e+20, 5.765690e+20, ..., 5.957598e+20,
#         5.709881e+20, 6.206148e+20],
#        [6.097352e+20, 5.583961e+20, 5.585144e+20, ..., 5.610048e+20,...
#  y: array([[6.234524e+20, 6.193407e+20, 5.765690e+20, ..., 5.957598e+20,
#         5.709881e+20, 6.206148e+20],
#        [6.097352e+20, 5.583961e+20, 5.585144e+20, ..., 5.610048e+20,...
# ERROR:root:TEXT
# Traceback (most recent call last):
#   File "/tmp/ipykernel_12857/2947564240.py", line 4, in test
#     np.testing.assert_equal(algorithm(Matrix(len(A),len(A), A), Matrix(len(B),len(B),B)).tolist(), np.matmul(A,B))
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 345, in assert_equal
#     return assert_array_equal(actual, desired, err_msg, verbose)
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 935, in assert_array_equal
#     verbose=verbose, header='Arrays are not equal')
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 844, in assert_array_compare
#     raise AssertionError(msg)
# AssertionError:
# Arrays are not equal
#
# Mismatched elements: 3766 / 4096 (91.9%)
# Max absolute difference: 96468992.
# Max relative difference: 2.19076606e-14
#  x: array([[4.503347e+21, 4.266203e+21, 4.889902e+21, ..., 4.751042e+21,
#         4.956331e+21, 4.908215e+21],
#        [4.782466e+21, 4.752668e+21, 4.965373e+21, ..., 4.984083e+21,...
#  y: array([[4.503347e+21, 4.266203e+21, 4.889902e+21, ..., 4.751042e+21,
#         4.956331e+21, 4.908215e+21],
#        [4.782466e+21, 4.752668e+21, 4.965373e+21, ..., 4.984083e+21,...
# ERROR:root:TEXT
# Traceback (most recent call last):
#   File "/tmp/ipykernel_12857/2947564240.py", line 4, in test
#     np.testing.assert_equal(algorithm(Matrix(len(A),len(A), A), Matrix(len(B),len(B),B)).tolist(), np.matmul(A,B))
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 345, in assert_equal
#     return assert_array_equal(actual, desired, err_msg, verbose)
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 935, in assert_array_equal
#     verbose=verbose, header='Arrays are not equal')
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 844, in assert_array_compare
#     raise AssertionError(msg)
# AssertionError:
# Arrays are not equal
#
# Mismatched elements: 3759 / 4096 (91.8%)
# Max absolute difference: 88080384.
# Max relative difference: 1.83970384e-14
#  x: array([[5.258223e+21, 5.440749e+21, 5.450849e+21, ..., 5.344735e+21,
#         4.821905e+21, 5.991646e+21],
#        [5.169720e+21, 4.929443e+21, 5.013302e+21, ..., 4.788842e+21,...
#  y: array([[5.258223e+21, 5.440749e+21, 5.450849e+21, ..., 5.344735e+21,
#         4.821905e+21, 5.991646e+21],
#        [5.169720e+21, 4.929443e+21, 5.013302e+21, ..., 4.788842e+21,...
# ERROR:root:TEXT
# Traceback (most recent call last):
#   File "/tmp/ipykernel_12857/2947564240.py", line 4, in test
#     np.testing.assert_equal(algorithm(Matrix(len(A),len(A), A), Matrix(len(B),len(B),B)).tolist(), np.matmul(A,B))
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 345, in assert_equal
#     return assert_array_equal(actual, desired, err_msg, verbose)
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 935, in assert_array_equal
#     verbose=verbose, header='Arrays are not equal')
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 844, in assert_array_compare
#     raise AssertionError(msg)
# AssertionError:
# Arrays are not equal
#
# Mismatched elements: 3786 / 4096 (92.4%)
# Max absolute difference: 72351744.
# Max relative difference: 1.57257035e-14
#  x: array([[5.382329e+21, 5.128645e+21, 3.925531e+21, ..., 4.659902e+21,
#         4.646281e+21, 4.826664e+21],
#        [4.865411e+21, 4.838448e+21, 3.734968e+21, ..., 4.409845e+21,...
#  y: array([[5.382329e+21, 5.128645e+21, 3.925531e+21, ..., 4.659902e+21,
#         4.646281e+21, 4.826664e+21],
#        [4.865411e+21, 4.838448e+21, 3.734968e+21, ..., 4.409845e+21,...
# ERROR:root:TEXT
# Traceback (most recent call last):
#   File "/tmp/ipykernel_12857/2947564240.py", line 4, in test
#     np.testing.assert_equal(algorithm(Matrix(len(A),len(A), A), Matrix(len(B),len(B),B)).tolist(), np.matmul(A,B))
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 345, in assert_equal
#     return assert_array_equal(actual, desired, err_msg, verbose)
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 935, in assert_array_equal
#     verbose=verbose, header='Arrays are not equal')
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 844, in assert_array_compare
#     raise AssertionError(msg)
# AssertionError:
# Arrays are not equal
#
# Mismatched elements: 3757 / 4096 (91.7%)
# Max absolute difference: 9.26941184e+08
# Max relative difference: 2.84872511e-14
#  x: array([[3.868863e+22, 3.611884e+22, 3.442983e+22, ..., 3.953826e+22,
#         4.073922e+22, 4.830520e+22],
#        [4.120334e+22, 3.700142e+22, 3.524901e+22, ..., 3.694467e+22,...
#  y: array([[3.868863e+22, 3.611884e+22, 3.442983e+22, ..., 3.953826e+22,
#         4.073922e+22, 4.830520e+22],
#        [4.120334e+22, 3.700142e+22, 3.524901e+22, ..., 3.694467e+22,...
# ERROR:root:TEXT
# Traceback (most recent call last):
#   File "/tmp/ipykernel_12857/2947564240.py", line 4, in test
#     np.testing.assert_equal(algorithm(Matrix(len(A),len(A), A), Matrix(len(B),len(B),B)).tolist(), np.matmul(A,B))
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 345, in assert_equal
#     return assert_array_equal(actual, desired, err_msg, verbose)
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 935, in assert_array_equal
#     verbose=verbose, header='Arrays are not equal')
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 844, in assert_array_compare
#     raise AssertionError(msg)
# AssertionError:
# Arrays are not equal
#
# Mismatched elements: 3802 / 4096 (92.8%)
# Max absolute difference: 9.05969664e+08
# Max relative difference: 2.36682104e-14
#  x: array([[4.299759e+22, 3.740364e+22, 3.640151e+22, ..., 3.782994e+22,
#         3.369252e+22, 3.712094e+22],
#        [4.482066e+22, 3.447289e+22, 3.613843e+22, ..., 3.793511e+22,...
#  y: array([[4.299759e+22, 3.740364e+22, 3.640151e+22, ..., 3.782994e+22,
#         3.369252e+22, 3.712094e+22],
#        [4.482066e+22, 3.447289e+22, 3.613843e+22, ..., 3.793511e+22,...
# ERROR:root:TEXT
# Traceback (most recent call last):
#   File "/tmp/ipykernel_12857/2947564240.py", line 4, in test
#     np.testing.assert_equal(algorithm(Matrix(len(A),len(A), A), Matrix(len(B),len(B),B)).tolist(), np.matmul(A,B))
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 345, in assert_equal
#     return assert_array_equal(actual, desired, err_msg, verbose)
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 935, in assert_array_equal
#     verbose=verbose, header='Arrays are not equal')
#   File "/home/katarzyna/.local/lib/python3.7/site-packages/numpy/testing/_private/utils.py", line 844, in assert_array_compare
#     raise AssertionError(msg)
# AssertionError:
# Arrays are not equal
#
# Mismatched elements: 3809 / 4096 (93%)
# Max absolute difference: 8.51443712e+08
# Max relative difference: 2.61095917e-14
#  x: array([[3.487046e+22, 4.253002e+22, 3.907174e+22, ..., 3.948974e+22,
#         4.198440e+22, 4.393598e+22],
#        [2.886095e+22, 3.595837e+22, 3.531196e+22, ..., 3.601269e+22,...
#  y: array([[3.487046e+22, 4.253002e+22, 3.907174e+22, ..., 3.948974e+22,
#         4.198440e+22, 4.393598e+22],
#        [2.886095e+22, 3.595837e+22, 3.531196e+22, ..., 3.601269e+22,...

# %% [markdown]
# ## Test result - Strassen on Large Numbers:
# We thus see that strassen fails earlier than originally anticipated as it fails before the 2^53. The results can be inspected below in the res dictionary. The key defined the power where the power is 2^power. We expect the floats to work until the power of 53.

# %%
res
# Out:
# {47: 'No failed computations',
#  50: 0.0257,
#  53: 0.6070000000000001,
#  56: 0.9096666666666667,
#  59: 0.9159999999999999,
#  62: 0.9203333333333333,
#  65: 0.9273333333333333,
#  68: 0.9263333333333333,
#  71: 0.9233333333333333,
#  74: 0.9203333333333333,
#  77: 0.9249999999999999}
